# %% [markdown]
# # Build a song recommender system

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load some music data & explore

# %%
song_data =pd.read_csv('Dataset/song_data.csv')

# %%
song_data
# Out:
#                                           user_id             song_id  \
# 0        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 2        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 3        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# 4        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273
# ...                                           ...                 ...
# 1116604  276e43ad698705e5011e5091f367d951b21246f5  SOWTYVO12AB0180BDA
# 1116605  276e43ad698705e5011e5091f367d951b21246f5  SOWZHOY12A6701F9FC
# 1116606  276e43ad698705e5011e5091f367d951b21246f5  SOXJOZW12A6701E90E
# 1116607  276e43ad698705e5011e5091f367d951b21246f5  SOXNKNC12A6701F7A8
# 1116608  276e43ad698705e5011e5091f367d951b21246f5  SOYRMVO12A6701D106
#
#          listen_count                                              title  \
# 0                   1                                           The Cove
# 1                   2                                    Entre Dos Aguas
# 2                   1                                           Stronger
# 3                   1                                     Constellations
# 4                   1                                       Learn To Fly
# ...               ...                                                ...
# 1116604             8                                   Surf Wax America
# 1116605             1                                      Kill The King
# 1116606             7  You Think I Ain't Worth A Dollar_ But I Feel L...
# 1116607             1                                         Superbeast
# 1116608             1                                          Keep Away
#
#                           artist  \
# 0                   Jack Johnson
# 1                  Paco De Lucia
# 2                     Kanye West
# 3                   Jack Johnson
# 4                   Foo Fighters
# ...                          ...
# 1116604                   Weezer
# 1116605                 Megadeth
# 1116606  Queens Of The Stone Age
# 1116607               Rob Zombie
# 1116608                 Godsmack
#
#                                                       song
# 0                                  The Cove - Jack Johnson
# 1                          Entre Dos Aguas - Paco De Lucia
# 2                                    Stronger - Kanye West
# 3                            Constellations - Jack Johnson
# 4                              Learn To Fly - Foo Fighters
# ...                                                    ...
# 1116604                          Surf Wax America - Weezer
# 1116605                           Kill The King - Megadeth
# 1116606  You Think I Ain't Worth A Dollar_ But I Feel L...
# 1116607                            Superbeast - Rob Zombie
# 1116608                               Keep Away - Godsmack
#
# [1116609 rows x 6 columns]

# %%
len(song_data)
# Out:
# 1116609

# %%
song_data.describe()
# Out:
#        listen_count
# count  1.116609e+06
# mean   3.290769e+00
# std    7.202534e+00
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    3.000000e+00
# max    9.200000e+02

# %% [markdown]
# ## Show the most popular songs in the dataset

# %%
#song_data['song'].show()
popular_song=pd.DataFrame(song_data['song'].value_counts().items(), columns=['song', 'count'])

# %%
popular_song
# Out:
#                                                    song  count
# 0                              Sehr kosmisch - Harmonia   5970
# 1                                          Undo - Björk   5281
# 2                        You're The One - Dwight Yoakam   4806
# 3     Dog Days Are Over (Radio Edit) - Florence + Th...   4536
# 4                               Revelry - Kings Of Leon   4339
# ...                                                 ...    ...
# 9947                        Made In The Dark - Hot Chip     16
# 9948                                 Trahison - Vitalic     15
# 9949                Marching Theme - Neutral Milk Hotel     15
# 9950          Younger Than Springtime - William Tabbert     12
# 9951                            Hubcap - Sleater-kinney     12
#
# [9952 rows x 2 columns]

# %%
popular_song.head(10)
# Out:
#                                                 song  count
# 0                           Sehr kosmisch - Harmonia   5970
# 1                                       Undo - Björk   5281
# 2                     You're The One - Dwight Yoakam   4806
# 3  Dog Days Are Over (Radio Edit) - Florence + Th...   4536
# 4                            Revelry - Kings Of Leon   4339
# 5  Horn Concerto No. 4 in E flat K495: II. Romanc...   3949
# 6                              Secrets - OneRepublic   3916
# 7                                 Tive Sim - Cartola   3185
# 8                     Fireflies - Charttraxx Karaoke   3171
# 9                           Hey_ Soul Sister - Train   3132

# %%
song_grouped = song_data.groupby(['song']).agg({'listen_count': 'count'}).reset_index()
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage']  = song_grouped['listen_count'].div(grouped_sum)*100
song_grouped.sort_values(['listen_count', 'song'], ascending = [0,1])
# Out:
#                                                    song  listen_count  \
# 7128                           Sehr kosmisch - Harmonia          5970
# 9083                                       Undo - Björk          5281
# 9879                     You're The One - Dwight Yoakam          4806
# 2068  Dog Days Are Over (Radio Edit) - Florence + Th...          4536
# 6775                            Revelry - Kings Of Leon          4339
# ...                                                 ...           ...
# 5126                        Made In The Dark - Hot Chip            16
# 5213                Marching Theme - Neutral Milk Hotel            15
# 8938                                 Trahison - Vitalic            15
# 3674                            Hubcap - Sleater-kinney            12
# 9891          Younger Than Springtime - William Tabbert            12
#
#       percentage
# 7128    0.534654
# 9083    0.472950
# 9879    0.430410
# 2068    0.406230
# 6775    0.388587
# ...          ...
# 5126    0.001433
# 5213    0.001343
# 8938    0.001343
# 3674    0.001075
# 9891    0.001075
#
# [9952 rows x 3 columns]

# %% [markdown]
# # Count the number of unique users in the data

# %%
users = song_data['user_id'].unique()

# %%
len(users)
# Out:
# 66346

# %%
songs = song_data['song'].unique()

# %%
len(songs)
# Out:
# 9952

# %% [markdown]
# # Create a song recommender

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data = train_test_split(song_data, test_size = 0.20, random_state=0)

# %%
train_data
# Out:
#                                          user_id             song_id  \
# 308223  4c1ea8245b67c2862e12f02b78e345cc7bdd7282  SOWVRVI12A6701E0B4
# 308537  6df2dd5a3bb9042da67ab82baf0727bca10ec05e  SOMEUED12A6701DBEA
# 234078  fd84fea1c5df235d73ebd3cf4a8c638ca1f3cfdb  SOBMCEI12A6D4F65BD
# 391502  d30183edf03302cdc25cb39798ae50a4395fa50f  SOCJAMC12A8C13F245
# 379458  9d4dfbd3614c1a4caab5f7fda723563befa626e8  SOJOIKI12AB0187525
# ...                                          ...                 ...
# 359783  243ca9574539ba638847f407e22ce0c3953ad391  SONUOOC12A8C136211
# 152315  35c63042c895bc5b198cab8e04b718469b7543ba  SOGHOUY12A8C143CB9
# 963395  109c70af3471629c753e693e741f805024b85b7d  SOKVZHI12A58A7A13E
# 117952  0de9ced79f560aa0e51c413fc54ec5d39f1e7386  SOPBFHP12A8C131F30
# 305711  8a5a3e5a252f0dca97b70c1da462fc373458b8a6  SOMEIKR12AB017CD99
#
#         listen_count                                              title  \
# 308223             7                                          Outshined
# 308537             1                                            Pump It
# 234078             2  My Lovin' (You're Never Gonna Get It) (LP Vers...
# 391502             2                                    Precious Things
# 379458             1                               Hero (Album Version)
# ...              ...                                                ...
# 359783             3                                          Heartbeat
# 152315             4                                           Dinosaur
# 963395             5                                    Everywhere I Go
# 117952            30                         Here_ There And Everywhere
# 305711            12                      La guitarra del joven soldado
#
#                   artist                                               song
# 308223       Soundgarden                            Outshined - Soundgarden
# 308537   Black Eyed Peas                          Pump It - Black Eyed Peas
# 234078          En Vogue  My Lovin' (You're Never Gonna Get It) (LP Vers...
# 391502         Tori Amos                        Precious Things - Tori Amos
# 379458           Skillet                     Hero (Album Version) - Skillet
# ...                  ...                                                ...
# 359783             Nneka                                  Heartbeat - Nneka
# 152315             Ke$ha                                   Dinosaur - Ke$ha
# 963395  Hollywood Undead                 Everywhere I Go - Hollywood Undead
# 117952         Erin Bode             Here_ There And Everywhere - Erin Bode
# 305711  Silvio Rodríguez   La guitarra del joven soldado - Silvio Rodríguez
#
# [893287 rows x 6 columns]

# %%
train_data_users_id = train_data['user_id'].unique()

# %%
len(train_data_users_id)
# Out:
# 66116

# %%
test_data
# Out:
#                                          user_id             song_id  \
# 333951  8f8f909dd86e77969d1f8753e10ac56c4c68aa72  SOZXQRQ12A6701C323
# 492194  d5a1b1b8142327cea378f262b96ef5675c8bff99  SOZKNSB12A8C140F11
# 525465  58907ab6047361c85eb92be39dcbd2f0eb924684  SOLFBXX12A8AE47A51
# 465962  f22c0aa5308322685a42fc10fa05ea3f4a6e96b4  SOWTAVD12B0B8090C2
# 162333  3134803ece9906f87bb1b64a63058ef26c603336  SOCCEFN12A6701C548
# ...                                          ...                 ...
# 15962   22b6baffe7de156c64060ebee5b3618f2aaf8c89  SOVWADY12AB0189C63
# 62745   4fd45ecbcc53725aa081527904bcfa166eb4e2c1  SOSACAB12AB01876E4
# 276130  53778a8a259574fb76b3252efb8b47e5aac5ae7a  SOFZSAT12AF72A0806
# 535667  bbcc1ebf3046eedfb94c89787b6500e8738964e4  SOIZFTE12AB0186842
# 827260  1efcde2bd5b58d83468f6a3bc62001b05350b566  SOUVTSM12AC468F6A7
#
#         listen_count                                              title  \
# 333951             2                                 Up Where We Belong
# 492194             6                                             Replay
# 525465             1           Surfacing (Live version) (Album Version)
# 465962             1                             Just Like You Imagined
# 162333             1  Tonight (Featuring Mobb Deep & Joe Hooker)(Alb...
# ...              ...                                                ...
# 15962              2                                Party In The U.S.A.
# 62745              1                                   From The Station
# 276130             7                              Youth Against Fascism
# 535667             1                                         Fuck Kitty
# 827260             3                                     Drop The World
#
#                               artist  \
# 333951  Joe Cocker / Jennifer Warnes
# 492194                          Iyaz
# 525465                      Slipknot
# 465962               Nine Inch Nails
# 162333          The Notorious B.I.G.
# ...                              ...
# 15962                    Miley Cyrus
# 62745                        Soltero
# 276130                   Sonic Youth
# 535667                      Frumpies
# 827260            Lil Wayne / Eminem
#
#                                                      song
# 333951  Up Where We Belong - Joe Cocker / Jennifer Warnes
# 492194                                      Replay - Iyaz
# 525465  Surfacing (Live version) (Album Version) - Sli...
# 465962           Just Like You Imagined - Nine Inch Nails
# 162333  Tonight (Featuring Mobb Deep & Joe Hooker)(Alb...
# ...                                                   ...
# 15962                   Party In The U.S.A. - Miley Cyrus
# 62745                          From The Station - Soltero
# 276130                Youth Against Fascism - Sonic Youth
# 535667                              Fuck Kitty - Frumpies
# 827260                Drop The World - Lil Wayne / Eminem
#
# [223322 rows x 6 columns]

# %%
test_data_users_id = test_data['user_id'].unique()

# %%
len(test_data_users_id)
# Out:
# 58601

# %% [markdown]
# ## Create a very simple popularity recommender

# %%
# Recommenders.popularity_recommender_py()

# %%
import Recommenders as Recommenders
pm = Recommenders.popularity_recommender_py()
pm.create(train_data, 'user_id', 'song')

# %% [markdown]
# ## Use the popularity model to make some predictions

# %%
pm.recommend(users[0])
# Out:
#                                        user_id  \
# 7128  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9083  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9879  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2068  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6775  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3614  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7116  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8846  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2718  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3486  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                    song  score  Rank
# 7128                           Sehr kosmisch - Harmonia   4812   1.0
# 9083                                       Undo - Björk   4211   2.0
# 9879                     You're The One - Dwight Yoakam   3819   3.0
# 2068  Dog Days Are Over (Radio Edit) - Florence + Th...   3624   4.0
# 6775                            Revelry - Kings Of Leon   3485   5.0
# 3614  Horn Concerto No. 4 in E flat K495: II. Romanc...   3188   6.0
# 7116                              Secrets - OneRepublic   3103   7.0
# 8846                                 Tive Sim - Cartola   2551   8.0
# 2718                     Fireflies - Charttraxx Karaoke   2525   9.0
# 3486                           Hey_ Soul Sister - Train   2505  10.0

# %%
pm.recommend(users[2])
# Out:
#                                        user_id  \
# 7128  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 9083  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 9879  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 2068  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 6775  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 3614  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 7116  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 8846  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 2718  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 3486  bd4c6e843f00bd476847fb75c47b4fb430a06856
#
#                                                    song  score  Rank
# 7128                           Sehr kosmisch - Harmonia   4812   1.0
# 9083                                       Undo - Björk   4211   2.0
# 9879                     You're The One - Dwight Yoakam   3819   3.0
# 2068  Dog Days Are Over (Radio Edit) - Florence + Th...   3624   4.0
# 6775                            Revelry - Kings Of Leon   3485   5.0
# 3614  Horn Concerto No. 4 in E flat K495: II. Romanc...   3188   6.0
# 7116                              Secrets - OneRepublic   3103   7.0
# 8846                                 Tive Sim - Cartola   2551   8.0
# 2718                     Fireflies - Charttraxx Karaoke   2525   9.0
# 3486                           Hey_ Soul Sister - Train   2505  10.0

# %% [markdown]
# ## Build a song recommender with personalization

# %%
# Recommenders.item_similarity_recommender_py()

# %% [markdown]
# ### Create an instance of item similarity based recommender class

# %%
is_model = Recommenders.item_similarity_recommender_py()
is_model.create(train_data, 'user_id', 'song')

# %% [markdown]
# ### Use the personalized model to make some song recommendations

# %%
#Print the songs for the user in training data
def print_user(user_id):
#user_id = users[0]
    user_items = is_model.get_user_items(user_id)
    #
    print("------------------------------------------------------------------------------------")
    print("Training data songs for the user userid: %s:" % user_id)
    print("------------------------------------------------------------------------------------")

    for user_item in user_items:
        print(user_item)

    print("----------------------------------------------------------------------")
    print("Recommendation process going on:")
    print("----------------------------------------------------------------------")

    #Recommend songs for the user using personalized model
    return is_model.recommend(user_id)

# %%
print_user(users[0])
# Out:
# ------------------------------------------------------------------------------------
# Training data songs for the user userid: b80344d063b5ccb3212f76538f3d9e43d87dca9e:
# ------------------------------------------------------------------------------------
# All That We Perceive - Thievery Corporation
# Apuesta Por El Rock 'N' Roll - Héroes del Silencio
# Paper Gangsta - Lady GaGa
# Neon - John Mayer
# Oh No - Andrew Bird
# Clarity - John Mayer
# Breakout - Foo Fighters
# Mykonos - Fleet Foxes
# Love Song For No One - John Mayer
# The Cove - Jack Johnson
# Our Swords (Soundtrack Version) - Band Of Horses
# Sehr kosmisch - Harmonia
# Drive - Incubus
# High and dry - Jorge Drexler
# Love Shack - The B-52's
# Heaven's gonna burn your eyes - Thievery Corporation feat. Emiliana Torrini
# Holes To Heaven - Jack Johnson
# Warning - Incubus
# Country Road - Jack Johnson / Paula Fuga
# Generator - Foo Fighters
# Are You In? - Incubus
# Stronger - Kanye West
# I'll Be Missing You (Featuring Faith Evans & 112)(Album Version) - Puff Daddy
# Champion - Kanye West
# Constellations - Jack Johnson
# The Middle - Jimmy Eat World
# Bigger Isn't Better - The String Cheese Incident
# Let It Be Sung - Jack Johnson / Matt Costa / Zach Gill / Dan Lebowitz / Steve Adams
# City Love - John Mayer
# Sun Giant - Fleet Foxes
# Behind The Sea [Live In Chicago] - Panic At The Disco
# 83 - John Mayer
# Entre Dos Aguas - Paco De Lucia
# The Old Saloon - The Lonely Island
# Trani - Kings Of Leon
# Moonshine - Jack Johnson
# Right Back - Sublime
# Learn To Fly - Foo Fighters
# ----------------------------------------------------------------------
# Recommendation process going on:
# ----------------------------------------------------------------------
# No. of unique songs for the user: 38
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :72857
#                                     user_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                          song     score rank
# 0                  Great Indoors - John Mayer  0.014196    1
# 1           Staple It Together - Jack Johnson  0.013492    2
# 2                 Crying Shame - Jack Johnson  0.012762    3
# 3              St. Patrick's Day - John Mayer  0.012540    4
# 4                    Back To You - John Mayer  0.012327    5
# 5                   If I Could - Jack Johnson  0.012244    6
# 6                      Posters - Jack Johnson  0.012165    7
# 7                     The News - Jack Johnson  0.011892    8
# 8                    Why Georgia - John Mayer  0.011706    9
# 9  All We Ever Do Is Say Goodbye - John Mayer  0.011405   10

# %%
print_user(users[1])
# Out:
# ------------------------------------------------------------------------------------
# Training data songs for the user userid: 85c1f87fea955d09b4bec2e36aee110927aedf9a:
# ------------------------------------------------------------------------------------
# The Best of Times - Sage Francis
# ----------------------------------------------------------------------
# Recommendation process going on:
# ----------------------------------------------------------------------
# No. of unique songs for the user: 1
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :1104
#                                     user_id  \
# 0  85c1f87fea955d09b4bec2e36aee110927aedf9a
# 1  85c1f87fea955d09b4bec2e36aee110927aedf9a
# 2  85c1f87fea955d09b4bec2e36aee110927aedf9a
# 3  85c1f87fea955d09b4bec2e36aee110927aedf9a
# 4  85c1f87fea955d09b4bec2e36aee110927aedf9a
# 5  85c1f87fea955d09b4bec2e36aee110927aedf9a
# 6  85c1f87fea955d09b4bec2e36aee110927aedf9a
# 7  85c1f87fea955d09b4bec2e36aee110927aedf9a
# 8  85c1f87fea955d09b4bec2e36aee110927aedf9a
# 9  85c1f87fea955d09b4bec2e36aee110927aedf9a
#
#                                              song     score rank
# 0        You Know Your Boy Did That - Swizz Beatz  0.050000    1
# 1                         Big Munny - Swizz Beatz  0.044248    2
# 2                       Deception - Blackalicious  0.042553    3
# 3                            Red Hot - Jurassic 5  0.039216    4
# 4   Work It Out - Jurassic 5 / Dave Matthews Band  0.035714    5
# 5                    Who Am I - Timbaland & Magoo  0.031579    6
# 6     I'm Him [Explicit Album Version] - Yung Joc  0.030612    7
# 7  There's A War Going On For Your Mind - Flobots  0.030612    8
# 8                              Jayou - Jurassic 5  0.028571    9
# 9                Crack The Shutters - Snow Patrol  0.028112   10

# %% [markdown]
# ## Apply personalized model to find similar songs to any song in the dataset

# %%
is_model.get_similar_items(['U Smile - Justin Bieber'])
# Out:
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :3325
#   user_id                                            song     score rank
# 0                                 Love Me - Justin Bieber  0.180927    1
# 1                        Somebody To Love - Justin Bieber  0.175371    2
# 2                    One Less Lonely Girl - Justin Bieber  0.168174    3
# 3          Eenie Meenie - Sean Kingston and Justin Bieber  0.165478    4
# 4                                One Time - Justin Bieber  0.165456    5
# 5                     Stuck In The Moment - Justin Bieber  0.159138    6
# 6                       That Should Be Me - Justin Bieber  0.153639    7
# 7                           Down To Earth - Justin Bieber  0.150000    8
# 8                        Never Let You Go - Justin Bieber  0.140691    9
# 9             Overboard - Justin Bieber / Jessica Jarrell  0.136026   10

# %% [markdown]
# # Quantitative comparison between the models

# %% [markdown]
# # Use the precision recall calculator class to calculate the evaluation measures

# %%
#Evaluation.precision_recall_calculator

# %%
import time
import Evaluation as Evaluation

start = time.time()

#Define what percentage of users to use for precision recall calculation
user_sample = 0.001

#Instantiate the precision_recall_calculator class
pr = Evaluation.precision_recall_calculator(test_data, train_data, pm, is_model)

#Call method to calculate precision and recall values
(pm_avg_precision_list, pm_avg_recall_list, ism_avg_precision_list, ism_avg_recall_list) = pr.calculate_measures(user_sample)

end = time.time()
print(end - start)
# Out:
# Length of user_test_and_training:58371
# Length of user sample:58
# Getting recommendations for user:cfa48bf4fc842afec45d96c915f51bd4d82624d7
# No. of unique songs for the user: 13
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :12419
# Getting recommendations for user:e5c448c5d49fd237a4bf6c27819159a4624b59b8
# No. of unique songs for the user: 12
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :26999
# Getting recommendations for user:a1f991f775927aa5eefd50d953c8fd36836b9b72
# No. of unique songs for the user: 14
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :20146
# Getting recommendations for user:35da0aff518d23c9f1b8d2e9c3a602ba3be8aac5
# No. of unique songs for the user: 7
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :9453
# Getting recommendations for user:05b9f6437b1e4c20a41077a2e09519282bc305a0
# No. of unique songs for the user: 9
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :43314
# Getting recommendations for user:8327025a968cbf59339ec47beb947c8221c3c75a
# No. of unique songs for the user: 22
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :41637
# Getting recommendations for user:238b3f2687f86f94f8d28a2c81e08e89ec573d5a
# No. of unique songs for the user: 16
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :58829
# Getting recommendations for user:6d5d211813f54f43cf8bbb6b4656907d13d3bd28
# No. of unique songs for the user: 32
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :63383
# Getting recommendations for user:868ab9545a0af6b41e34d2d2a9f297c0f4c235bd
# No. of unique songs for the user: 5
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :7636
# Getting recommendations for user:ccb97c4048487da53c07edeb4edd3b00be95e237
# No. of unique songs for the user: 8
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :21314
# Getting recommendations for user:0d937a90c5002ecca4cbfb4f3070d7f0b05b1db6
# No. of unique songs for the user: 16
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :54501
# Getting recommendations for user:5e60f3d45ba241bb48a7319ee609c8ee89d58796
# No. of unique songs for the user: 9
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :12178
# Getting recommendations for user:85f65b3dd7ac933862cfb562098785e96e7cb4f8
# No. of unique songs for the user: 8
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :14183
# Getting recommendations for user:7f571319ed8dc2fda71b159e582fb334a878eaca
# No. of unique songs for the user: 14
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :35151
# Getting recommendations for user:6e53e114863319cce51cd83457e2ce1577ae4440
# No. of unique songs for the user: 29
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :70920
# Getting recommendations for user:1b32dd9fcaa74bf4261e66349ed7965c2572ff5a
# No. of unique songs for the user: 6
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :13469
# Getting recommendations for user:d236efdb5a7283fefb8bb462a1111b91c9fe4e3f
# No. of unique songs for the user: 8
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :31634
# Getting recommendations for user:e71b0f35edc9624c6e380b97e883eb84bc1c7b1d
# No. of unique songs for the user: 20
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :43461
# Getting recommendations for user:534b2b8665692be248efc2e28633306bc19d9a1c
# No. of unique songs for the user: 7
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :14986
# Getting recommendations for user:d2c36c14e7a725ed6dfa9c2b9f7f452421022fe4
# No. of unique songs for the user: 5
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :13816
# Getting recommendations for user:d73630d488f498fcba06b1be7d0d0efc4c0e4c7d
# No. of unique songs for the user: 23
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :52441
# Getting recommendations for user:ab6b4ba4ee7b01dbd6a16e01026f498123b9f512
# No. of unique songs for the user: 11
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :10034
# Getting recommendations for user:bd1db95232acfabb9f0da2e10ad862a32de040c4
# No. of unique songs for the user: 7
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :24609
# Getting recommendations for user:bff6c635a6de5d7c4b567ed5dcda20a6c79cbfc1
# No. of unique songs for the user: 4
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :16393
# Getting recommendations for user:35c5eda8c412c1333c056cbeaaf3e706faa68ec0
# No. of unique songs for the user: 10
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :21967
# Getting recommendations for user:b92090abae74c3c87c2d8e0ee995d302edd9d6e9
# No. of unique songs for the user: 19
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :22345
# Getting recommendations for user:180913cbb7c8fa010df5c98e20df7be462114320
# No. of unique songs for the user: 12
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :24400
# Getting recommendations for user:87f84f87d06d360944e24b0e47a7c5c26c671743
# No. of unique songs for the user: 4
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :7516
# Getting recommendations for user:0027f373a116bb4223ce63c0358f11619b52da6c
# No. of unique songs for the user: 11
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :36383
# Getting recommendations for user:5f221ee77b6249895bfebaf03b1340ef544d2acb
# No. of unique songs for the user: 7
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :9683
# Getting recommendations for user:e66aa61e284550a1688741b4df2811aa6ea4cc84
# No. of unique songs for the user: 9
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :13587
# Getting recommendations for user:65944626bc2f29b1c97705be2487117515a13a1d
# No. of unique songs for the user: 13
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :23368
# Getting recommendations for user:85a73acfd61eee228726178720952561c012efbc
# No. of unique songs for the user: 14
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :38005
# Getting recommendations for user:74691063ac98116875debe5586bc9e28076c9019
# No. of unique songs for the user: 13
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :21621
# Getting recommendations for user:6be761918ff6c7d47162254aa11022d4da6c0c63
# No. of unique songs for the user: 6
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :42635
# Getting recommendations for user:9be39610627f6969cbc6f44a351532d7dc92ebda
# No. of unique songs for the user: 3
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :3582
# Getting recommendations for user:da3c0e4e7b67aa46d81e74beefd488e64a3a5003
# No. of unique songs for the user: 20
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :26824
# Getting recommendations for user:8709d3cf50b651da32f8371939a91667c66170d3
# No. of unique songs for the user: 6
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :5811
# Getting recommendations for user:f3ddf9647dcf817732a1c548110083f5736dfd9d
# No. of unique songs for the user: 2
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :2239
# Getting recommendations for user:7f173bed32975199fcdf95b3d4bcbcd7012af746
# No. of unique songs for the user: 14
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :73069
# Getting recommendations for user:d4473ba52bb5b939693e34e8f83260536dfb39c8
# No. of unique songs for the user: 15
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :17529
# Getting recommendations for user:f03a185bedac54634a9d5706ea386fb4d74b5e4f
# No. of unique songs for the user: 15
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :21313
# Getting recommendations for user:b753b0c8f45b7203b439aa3bb04fc30eff160c15
# No. of unique songs for the user: 13
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :26020
# Getting recommendations for user:cc3402dbfbbdda5791bdea0431257591e74f15fa
# No. of unique songs for the user: 18
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :43820
# Getting recommendations for user:3f9ed694a79835c921ef6d94acd28f876c1d901e
# No. of unique songs for the user: 34
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :73076
# Getting recommendations for user:67670919b95b7e286b89023ad72d69fdf922ee1a
# No. of unique songs for the user: 27
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :50782
# Getting recommendations for user:f4abc9f126cb67af7f9c90fdc0b43e1cb17b7d11
# No. of unique songs for the user: 9
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :14838
# Getting recommendations for user:af367e6215ba04f1487fb18b9dcba4a2aad33d64
# No. of unique songs for the user: 20
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :33370
# Getting recommendations for user:8cf71727c8ff4e0c299a8d595c82024968548ed5
# No. of unique songs for the user: 24
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :28640
# Getting recommendations for user:eb9fad0ce8da7f37fc174b05361ec5c48012e491
# No. of unique songs for the user: 27
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :45479
# Getting recommendations for user:623721195f7ea87c777f76649a1c519269952f55
# No. of unique songs for the user: 8
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :9471
# Getting recommendations for user:48099576388838c00f207e0cb09bf65671941ce7
# No. of unique songs for the user: 11
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :23170
# Getting recommendations for user:907f4dcf51f30b78edf7d0adf94419edc1891515
# No. of unique songs for the user: 5
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :12665
# Getting recommendations for user:84b8ea13990667ef08990d487458b91da9ff2089
# No. of unique songs for the user: 18
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :45906
# Getting recommendations for user:8b9e8028dae259b7024374965aa574c995041d50
# No. of unique songs for the user: 21
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :37570
# Getting recommendations for user:b9a9dd92c967ef87809556e0b86a80bf52cd0b0e
# No. of unique songs for the user: 30
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :48064
# Getting recommendations for user:f366eaec4e111093cf487929ded9d5ac36206e4a
# No. of unique songs for the user: 5
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :15195
# Getting recommendations for user:20b44e3fef19d978af29c48c16149f16ebda7b4f
# No. of unique songs for the user: 27
# No. of unique songs in the training set: 9952
# Non zero values in cooccurence_matrix :62281
# 45234.19894576073

# %% [markdown]
# # Code to plot precision recall curve

# %%
import pylab as pl

#Method to generate precision and recall curve
def plot_precision_recall(m1_precision_list, m1_recall_list, m1_label, m2_precision_list, m2_recall_list, m2_label):
    pl.clf()    
    pl.plot(m1_recall_list, m1_precision_list, label=m1_label)
    pl.plot(m2_recall_list, m2_precision_list, label=m2_label)
    pl.xlabel('Recall')
    pl.ylabel('Precision')
    pl.ylim([0.0, 0.20])
    pl.xlim([0.0, 0.20])
    pl.title('Precision-Recall curve')
    #pl.legend(loc="upper right")
    pl.legend(loc=9, bbox_to_anchor=(0.5, -0.2))
    pl.show()

# %%
print("Plotting precision recall curves.")

plot_precision_recall(pm_avg_precision_list, pm_avg_recall_list, "popularity_model",
                      ism_avg_precision_list, ism_avg_recall_list, "item_similarity_model")
# Out:
# Plotting precision recall curves.

# %%
from sklearn.externals import joblib
print("Plotting precision recall curves for a larger subset of data (100,000 rows) (user sample = 0.005).")

#Read the persisted files 
pm_avg_precision_list = joblib.load('pm_avg_precision_list_3.pkl')
pm_avg_recall_list = joblib.load('pm_avg_recall_list_3.pkl')
ism_avg_precision_list = joblib.load('ism_avg_precision_list_3.pkl')
ism_avg_recall_list = joblib.load('ism_avg_recall_list_3.pkl')

print("Plotting precision recall curves.")
plot_precision_recall(pm_avg_precision_list, pm_avg_recall_list, "popularity_model",
                      ism_avg_precision_list, ism_avg_recall_list, "item_similarity_model")
# Out:
# Plotting precision recall curves for a larger subset of data (100,000 rows) (user sample = 0.005).
# /home/dipesh/anaconda3/envs/venv/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-b93fd6d74591> in <module>
#       3
#       4 #Read the persisted files
# ----> 5 pm_avg_precision_list = joblib.load('pm_avg_precision_list_3.pkl')
#       6 pm_avg_recall_list = joblib.load('pm_avg_recall_list_3.pkl')
#       7 ism_avg_precision_list = joblib.load('ism_avg_precision_list_3.pkl')
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     595             obj = _unpickle(fobj)
#     596     else:
# --> 597         with open(filename, 'rb') as f:
#     598             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     599                 if isinstance(fobj, _basestring):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pm_avg_precision_list_3.pkl'

# %% [markdown]
# # Matrix Factorization based Recommender System

# %%
# pip install sparsesvd

# %%
#Code source written with help from: 
#http://antoinevastel.github.io/machine%20learning/python/2016/02/14/svd-recommender-system.html

import math as mt
import csv
from sparsesvd import sparsesvd #used for matrix factorization
import numpy as np
from scipy.sparse import csc_matrix #used for sparse matrix
from scipy.sparse.linalg import * #used for matrix multiplication

#Note: You may need to install the library sparsesvd. Documentation for 
#sparsesvd method can be found here:
#https://pypi.python.org/pypi/sparsesvd/

# %% [markdown]
# ## Methods to compute SVD and recommendations

# %%
#constants defining the dimensions of our User Rating Matrix (URM)
MAX_PID = 4
MAX_UID = 5

#Compute SVD of the user ratings matrix
def computeSVD(urm, K):
    U, s, Vt = sparsesvd(urm, K)

    dim = (len(s), len(s))
    S = np.zeros(dim, dtype=np.float32)
    for i in range(0, len(s)):
        S[i,i] = mt.sqrt(s[i])

    U = csc_matrix(np.transpose(U), dtype=np.float32)
    S = csc_matrix(S, dtype=np.float32)
    Vt = csc_matrix(Vt, dtype=np.float32)
    
    return U, S, Vt

#Compute estimated rating for the test user
def computeEstimatedRatings(urm, U, S, Vt, uTest, K, test):
    rightTerm = S*Vt 

    estimatedRatings = np.zeros(shape=(MAX_UID, MAX_PID), dtype=np.float16)
    for userTest in uTest:
        prod = U[userTest, :]*rightTerm
        #we convert the vector to dense format in order to get the indices 
        #of the movies with the best estimated ratings 
        estimatedRatings[userTest, :] = prod.todense()
        recom = (-estimatedRatings[userTest, :]).argsort()[:250]
    return recom

# %% [markdown]
# ## Use SVD to make predictions for a test user id, say 4

# %%
#Used in SVD calculation (number of latent factors)
K=2

#Initialize a sample user rating matrix
urm = np.array([[3, 1, 2, 3],[4, 3, 4, 3],[3, 2, 1, 5], [1, 6, 5, 2], [5, 0,0 , 0]])
urm = csc_matrix(urm, dtype=np.float32)

#Compute SVD of the input user ratings matrix
U, S, Vt = computeSVD(urm, K)

#Test user set as user_id 4 with ratings [0, 0, 5, 0]
uTest = [4]
print("User id for whom recommendations are needed: %d" % uTest[0])

#Get estimated rating for test user
print("Predictied ratings:")
uTest_recommended_items = computeEstimatedRatings(urm, U, S, Vt, uTest, K, True)
print(uTest_recommended_items)
