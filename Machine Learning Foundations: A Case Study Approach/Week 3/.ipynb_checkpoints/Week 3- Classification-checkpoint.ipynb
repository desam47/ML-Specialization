# %% [markdown]
# # Analyze Product Sentiment

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read product review data

# %%
products =pd.read_csv('amazon_baby.csv')

# %% [markdown]
# # Explore data

# %%
products
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 0       These flannel wipes are OK, but in my opinion ...       3
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
# [183531 rows x 3 columns]

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183531 entries, 0 to 183530
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   name    183213 non-null  object
#  1   review  182702 non-null  object
#  2   rating  183531 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 4.2+ MB

# %%
products.describe()
# Out:
#               rating
# count  183531.000000
# mean        4.120448
# std         1.285017
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000

# %%
products['name'].nunique()
# Out:
# 32417

# %%
products['name'].unique()
# Out:
# array(['Planetwise Flannel Wipes', 'Planetwise Wipe Pouch',
#        'Annas Dream Full Quilt with 2 Shams', ...,
#        'Abstract 2 PK Baby / Toddler Training Cup (Pink)',
#        'Baby Food Freezer Tray - Bacteria Resistant, BPA and Phthalate Free - FREE Recipe E-book - Silicone Storage Container with Lid for Homemade Baby Food - 9 Easy-Out Portions - Lifetime Guarantee - Purple',
#        'Best 2 Pack Baby Car Shade for Kids - Window Shade Baby - Cheapest Baby Sun Shade with Excellent Quality - Great Protection Car Window Shade for Travel, Trips, or Just for Shade - Better Than Britax and Brica - Pop Open Window Shade Cling That Folds to the Size of Your Hand - Twice As Strong As Competitors - Lifetime Money Back Guarantee'],
#       dtype=object)

# %%
#products['name'].value_counts().reset_index(name=('name' ,'counts'))

# %%
pd.DataFrame(products['name'].value_counts().items(), columns=['name', 'count'])
# Out:
#                                                     name  count
# 0                       Vulli Sophie the Giraffe Teether    785
# 1      Simple Wishes Hands-Free Breastpump Bra, Pink,...    562
# 2      Infant Optics DXR-5 2.4 GHz Digital Video Baby...    561
# 3                         Baby Einstein Take Along Tunes    547
# 4      Cloud b Twilight Constellation Night Light, Tu...    520
# ...                                                  ...    ...
# 32412  Cute Cartoon Animal Style Baby Kids Cotton Leg...      1
# 32413       Britax Parkway Booster Car Seat, Cowmooflage      1
# 32414                 DISNEY PRINCESS [6PC] MEALTIME SET      1
# 32415  12V Universal Travel Baby Kid Bottle Warmer He...      1
# 32416  Baby Trend Velocity Travel Jogger System, Volcano      1
#
# [32417 rows x 2 columns]

# %% [markdown]
# # Perform text cleaning

# %%
products = products.fillna({'review':''})  # fill in N/A's in the review column

# %%
products
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 0       These flannel wipes are OK, but in my opinion ...       3
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
# [183531 rows x 3 columns]

# %%
def remove_punctuation(text):
    import string
    return text.translate(str.maketrans('','',string.punctuation))

products['review_clean'] = products['review'].apply(remove_punctuation)

# %%
products.head(5)
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating  \
# 0  These flannel wipes are OK, but in my opinion ...       3
# 1  it came early and was not disappointed. i love...       5
# 2  Very soft and comfortable and warmer than it l...       5
# 3  This is a product well worth the purchase.  I ...       5
# 4  All of my kids have cried non-stop when I trie...       5
#
#                                         review_clean
# 0  These flannel wipes are OK but in my opinion n...
# 1  it came early and was not disappointed i love ...
# 2  Very soft and comfortable and warmer than it l...
# 3  This is a product well worth the purchase  I h...
# 4  All of my kids have cried nonstop when I tried...

# %% [markdown]
# # Examine the reivews for the most-reviewed product

# %%
giraffe_reviews = products[products['name']=='Vulli Sophie the Giraffe Teether']

# %%
giraffe_reviews
# Out:
#                                     name  \
# 34313   Vulli Sophie the Giraffe Teether
# 34314   Vulli Sophie the Giraffe Teether
# 34315   Vulli Sophie the Giraffe Teether
# 34316   Vulli Sophie the Giraffe Teether
# 34317   Vulli Sophie the Giraffe Teether
# ...                                  ...
# 159649  Vulli Sophie the Giraffe Teether
# 159650  Vulli Sophie the Giraffe Teether
# 159651  Vulli Sophie the Giraffe Teether
# 159652  Vulli Sophie the Giraffe Teether
# 159653  Vulli Sophie the Giraffe Teether
#
#                                                    review  rating  \
# 34313   He likes chewing on all the parts especially t...       5
# 34314   My son loves this toy and fits great in the di...       5
# 34315   There really should be a large warning on the ...       1
# 34316   All the moms in my moms' group got Sophie for ...       5
# 34317   I was a little skeptical on whether Sophie was...       5
# ...                                                   ...     ...
# 159649  My baby loves her Sophie Chew Toy. She can che...       5
# 159650  Sophie the Giraffe was a big hit at the baby s...       5
# 159651  quick shipping and perfect product. I would pu...       5
# 159652  My baby who is currently teething love his Sop...       5
# 159653  I know several baits that are enjoying the sof...       5
#
#                                              review_clean
# 34313   He likes chewing on all the parts especially t...
# 34314   My son loves this toy and fits great in the di...
# 34315   There really should be a large warning on the ...
# 34316   All the moms in my moms group got Sophie for t...
# 34317   I was a little skeptical on whether Sophie was...
# ...                                                   ...
# 159649  My baby loves her Sophie Chew Toy She can chew...
# 159650  Sophie the Giraffe was a big hit at the baby s...
# 159651  quick shipping and perfect product I would pur...
# 159652  My baby who is currently teething love his Sop...
# 159653  I know several baits that are enjoying the sof...
#
# [785 rows x 4 columns]

# %%
len(giraffe_reviews)
# Out:
# 785

# %%
giraffe_reviews_count=giraffe_reviews['rating'].value_counts().rename_axis('Rating').to_frame('counts')

# %%
giraffe_reviews_count
# Out:
#         counts
# Rating
# 5          535
# 4           95
# 3           62
# 1           56
# 2           37

# %%
giraffe_reviews_count.plot(kind='bar', figsize=(10, 6))
plt.show()

# %% [markdown]
# # Building a sentiment classifier

# %% [markdown]
# ## Build word count vectors

# %%
from collections import Counter

# %%
#products['word_count']= [Counter(x) for x in products['review_clean'].str.split()]
products['word_count']= products['review_clean'].str.split().apply(Counter)

# %%
products
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating  \
# 0       These flannel wipes are OK, but in my opinion ...       3
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
#                                              review_clean  \
# 0       These flannel wipes are OK but in my opinion n...
# 1       it came early and was not disappointed i love ...
# 2       Very soft and comfortable and warmer than it l...
# 3       This is a product well worth the purchase  I h...
# 4       All of my kids have cried nonstop when I tried...
# ...                                                   ...
# 183526  Such a great idea very handy to have and look ...
# 183527  This product rocks  It is a great blend of fun...
# 183528  This item looks great and cool for my kidsI kn...
# 183529  I am extremely happy with this product I have ...
# 183530  I love this product very mush  I have bought m...
#
#                                                word_count
# 0       {'These': 1, 'flannel': 1, 'wipes': 2, 'are': ...
# 1       {'it': 3, 'came': 1, 'early': 1, 'and': 3, 'wa...
# 2       {'Very': 1, 'soft': 1, 'and': 2, 'comfortable'...
# 3       {'This': 1, 'is': 4, 'a': 2, 'product': 2, 'we...
# 4       {'All': 1, 'of': 1, 'my': 1, 'kids': 2, 'have'...
# ...                                                   ...
# 183526  {'Such': 1, 'a': 1, 'great': 2, 'idea': 1, 've...
# 183527  {'This': 1, 'product': 2, 'rocks': 1, 'It': 1,...
# 183528  {'This': 1, 'item': 1, 'looks': 1, 'great': 2,...
# 183529  {'I': 9, 'am': 2, 'extremely': 1, 'happy': 1, ...
# 183530  {'I': 2, 'love': 1, 'this': 1, 'product': 1, '...
#
# [183531 rows x 5 columns]

# %% [markdown]
# # Define what is positive and negative sentiment

# %%
products_count = products['rating'].value_counts().rename_axis('Rating').to_frame('counts')
products_count
# Out:
#         counts
# Rating
# 5       107054
# 4        33205
# 3        16779
# 1        15183
# 2        11310

# %%
products_count.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Rating') # add to x-label to the plot
plt.ylabel('Counts') # add y-label to the plot
plt.title('Distribution of values')

plt.show()

# %%
products['sentiment'] = products['rating'].apply(lambda rating : +1 if rating > 3 else 0)
# Out:
# /home/dipesh/anaconda3/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
products
# Out:
#                                                      name  \
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# 5       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating  \
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# 5       When the Binky Fairy came to our house, we did...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
#                                              review_clean  sentiment
# 1       it came early and was not disappointed i love ...          1
# 2       Very soft and comfortable and warmer than it l...          1
# 3       This is a product well worth the purchase  I h...          1
# 4       All of my kids have cried nonstop when I tried...          1
# 5       When the Binky Fairy came to our house we didn...          1
# ...                                                   ...        ...
# 183526  Such a great idea very handy to have and look ...          1
# 183527  This product rocks  It is a great blend of fun...          1
# 183528  This item looks great and cool for my kidsI kn...          1
# 183529  I am extremely happy with this product I have ...          1
# 183530  I love this product very mush  I have bought m...          1
#
# [166752 rows x 5 columns]

# %%
products_sentiment = products['sentiment'].value_counts().rename_axis('sentiment').to_frame('counts')
products_sentiment
# Out:
#            counts
# sentiment
# 1          140259
# 0           26493

# %%
products_sentiment.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Sentiment') # add to x-label to the plot
plt.ylabel('Counts') # add y-label to the plot
plt.title('Distribution of values')

plt.show()

# %% [markdown]
# # Train our sentiment classifier

# %% [markdown]
# ## Split into training and test sets

# %%
from sklearn.model_selection import train_test_split
X = products['review_clean']
y = products['sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
# 170560    This is going to be a stocking stuffer for a 1...
# 82460     I bought this for My 2 yr old I had it persona...
# 95808     Appears to be a good quality item and does a n...
# 61220     Its a perfectly fine bed  No complaints nothin...
# 34228     When our son was a newborn he had a really tou...
#                                 ...
# 107443    We swaddled my daughter in AA muslin blankets ...
# 105588    The idea is great but one of the speakers are ...
# 167632    At 15 months my toddler suddenly wouldnt get i...
# 129821    Bought this for a gift for our daughterinlaw t...
# 47911     mine came with a small scratch on it but the i...
# Name: review_clean, Length: 133401, dtype: object

# %%
X_test
# Out:
# 103733    Got this for a friend for her baby shower Love...
# 157975    Ok so obviously there isnt much to say about a...
# 127693    We have a couple versions of Tommie Tippie and...
# 113718    Ordered washcloths pictured but others were se...
# 20416     perfect for what its supposed to be my 9 month...
#                                 ...
# 62773     I bought this for my almost 3 year old who is ...
# 183290    The Argos 3in1 seat is pretty much identical t...
# 608       I paid 3999 for this on Amazon and could have ...
# 89302     I thought that if Medela produces and sells th...
# 162123    Tried these and two other types of cloth diape...
# Name: review_clean, Length: 33351, dtype: object

# %%
y_train
# Out:
# 170560    1
# 82460     0
# 95808     1
# 61220     1
# 34228     1
#          ..
# 107443    1
# 105588    0
# 167632    1
# 129821    1
# 47911     1
# Name: sentiment, Length: 133401, dtype: int64

# %%
y_test
# Out:
# 103733    1
# 157975    1
# 127693    1
# 113718    0
# 20416     1
#          ..
# 62773     1
# 183290    1
# 608       0
# 89302     0
# 162123    1
# Name: sentiment, Length: 33351, dtype: int64

# %% [markdown]
# # Build the word count vector for each review

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()

train_matrix = cv.fit_transform(X_train)

test_matrix = cv.transform(X_test)

# %%
train_matrix
# Out:
# <133401x121198 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7079723 stored elements in Compressed Sparse Row format>

# %%
test_matrix
# Out:
# <33351x121198 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1763186 stored elements in Compressed Sparse Row format>

# %%
print (cv.vocabulary_)
# Out:
, 'where': 118024, 'sitting': 95694, 'once': 73978, 'week': 117150, 'take': 104485, 'out': 75622, 'side': 94874, 'hose': 53152, 'bad': 14309, 'boy': 19245, 'potette': 81644, '20': 1547, 'now': 72425, 'oldest': 73776, 'almost': 9751, '22': 1833, 'used': 113817, 'timesmy': 108160, 'youngest': 120803, '25': 2019, 'using': 114166, 'itback': 57326, 'mine': 66609, 'wasnt': 116551, 'amazon': 10120, 'simple': 95312, 'pale': 77221, 'green': 48779, 'color': 26141, 'never': 70589, 'broke': 20062, 'still': 100815, 'glad': 47301, 'rid': 89445, 'gem': 46670, 'passed': 77803, 'potty': 81676, 'seats': 92429, 'past': 77847, 'will': 118529, 'hang': 50226, 'onto': 74571, 'grand': 48194, 'kidssmall': 59340, 'compact': 26857, 'folded': 44081, 'easy': 37419, 'vehicle': 114661, 'space': 98594, 'necessary': 70095, 'along': 9804, 'super': 10307 ...

# %% [markdown]
# # Train a sentiment classifier with logistic regression

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

model = LogisticRegression()

result1 = model.fit(train_matrix, y_train)
result1
# Out:
# /home/dipesh/anaconda3/envs/venv/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_class = result1.predict(test_matrix)

# %%
y_pred_class
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
from sklearn import metrics

print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(model.score(test_matrix, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.93

# %%
from sklearn.metrics import classification_report, confusion_matrix
cm = confusion_matrix(y_test, result1.predict(test_matrix))
fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0, 1), ticklabels=('Predicted 0', 'Predicted 1'))
ax.yaxis.set(ticks=(0, 1), ticklabels=('Actual 0', 'Actual 1'))
ax.set_ylim(1.5, -0.5)
for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i, j], ha='center', va='center', color='red')
plt.show()

# %%
print(classification_report(y_test, result1.predict(test_matrix)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.72      0.77      5362
#            1       0.95      0.97      0.96     27989
#
#     accuracy                           0.93     33351
#    macro avg       0.88      0.85      0.86     33351
# weighted avg       0.93      0.93      0.93     33351

# %%
y_pred_proba = result1.predict_proba(test_matrix)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
y_pred_proba
# Out:
# array([0.98657624, 0.81242236, 0.98906238, ..., 0.49960167, 0.65309226,
#        0.98677516])

# %% [markdown]
# # Apply the sentiment classifier to better understand the Giraffe reviews

# %%
review_clean1= cv.transform(products['review_clean'])

# %%
review_clean1
# Out:
# <166752x121198 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8842909 stored elements in Compressed Sparse Row format>

# %%
products['predicted_sentiment'] = result1.predict_proba(review_clean1)[::,1]
# Out:
# /home/dipesh/anaconda3/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
products
# Out:
#                                                      name  \
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# 5       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating  \
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# 5       When the Binky Fairy came to our house, we did...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
#                                              review_clean  sentiment  \
# 1       it came early and was not disappointed i love ...          1
# 2       Very soft and comfortable and warmer than it l...          1
# 3       This is a product well worth the purchase  I h...          1
# 4       All of my kids have cried nonstop when I tried...          1
# 5       When the Binky Fairy came to our house we didn...          1
# ...                                                   ...        ...
# 183526  Such a great idea very handy to have and look ...          1
# 183527  This product rocks  It is a great blend of fun...          1
# 183528  This item looks great and cool for my kidsI kn...          1
# 183529  I am extremely happy with this product I have ...          1
# 183530  I love this product very mush  I have bought m...          1
#
#         predicted_sentiment
# 1                  0.800097
# 2                  0.981367
# 3                  0.999909
# 4                  0.997368
# 5                  0.999992
# ...                     ...
# 183526             0.965186
# 183527             0.973874
# 183528             0.980114
# 183529             0.999713
# 183530             0.996411
#
# [166752 rows x 6 columns]

# %%
giraffe_reviews = products[products['name']== 'Vulli Sophie the Giraffe Teether']

# %%
giraffe_reviews
# Out:
#                                     name  \
# 34313   Vulli Sophie the Giraffe Teether
# 34314   Vulli Sophie the Giraffe Teether
# 34315   Vulli Sophie the Giraffe Teether
# 34316   Vulli Sophie the Giraffe Teether
# 34317   Vulli Sophie the Giraffe Teether
# ...                                  ...
# 159649  Vulli Sophie the Giraffe Teether
# 159650  Vulli Sophie the Giraffe Teether
# 159651  Vulli Sophie the Giraffe Teether
# 159652  Vulli Sophie the Giraffe Teether
# 159653  Vulli Sophie the Giraffe Teether
#
#                                                    review  rating  \
# 34313   He likes chewing on all the parts especially t...       5
# 34314   My son loves this toy and fits great in the di...       5
# 34315   There really should be a large warning on the ...       1
# 34316   All the moms in my moms' group got Sophie for ...       5
# 34317   I was a little skeptical on whether Sophie was...       5
# ...                                                   ...     ...
# 159649  My baby loves her Sophie Chew Toy. She can che...       5
# 159650  Sophie the Giraffe was a big hit at the baby s...       5
# 159651  quick shipping and perfect product. I would pu...       5
# 159652  My baby who is currently teething love his Sop...       5
# 159653  I know several baits that are enjoying the sof...       5
#
#                                              review_clean  sentiment  \
# 34313   He likes chewing on all the parts especially t...          1
# 34314   My son loves this toy and fits great in the di...          1
# 34315   There really should be a large warning on the ...          0
# 34316   All the moms in my moms group got Sophie for t...          1
# 34317   I was a little skeptical on whether Sophie was...          1
# ...                                                   ...        ...
# 159649  My baby loves her Sophie Chew Toy She can chew...          1
# 159650  Sophie the Giraffe was a big hit at the baby s...          1
# 159651  quick shipping and perfect product I would pur...          1
# 159652  My baby who is currently teething love his Sop...          1
# 159653  I know several baits that are enjoying the sof...          1
#
#         predicted_sentiment
# 34313              0.999336
# 34314              0.999232
# 34315              0.125601
# 34316              0.985931
# 34317              0.398167
# ...                     ...
# 159649             0.995836
# 159650             0.898177
# 159651             0.999841
# 159652             0.994601
# 159653             0.902921
#
# [723 rows x 6 columns]

# %% [markdown]
# # Sort the Giraffe reviews according to predicted sentiment

# %%
giraffe_reviews = giraffe_reviews.sort_values('predicted_sentiment', ascending=False)

# %%
giraffe_reviews
# Out:
#                                    name  \
# 34892  Vulli Sophie the Giraffe Teether
# 34434  Vulli Sophie the Giraffe Teether
# 34442  Vulli Sophie the Giraffe Teether
# 34523  Vulli Sophie the Giraffe Teether
# 34515  Vulli Sophie the Giraffe Teether
# ...                                 ...
# 35018  Vulli Sophie the Giraffe Teether
# 34732  Vulli Sophie the Giraffe Teether
# 34748  Vulli Sophie the Giraffe Teether
# 34556  Vulli Sophie the Giraffe Teether
# 34687  Vulli Sophie the Giraffe Teether
#
#                                                   review  rating  \
# 34892  Sophie, oh Sophie, your time has come. My gran...       5
# 34434  My Mom-in-Law bought Sophie for my son when he...       5
# 34442  Yes, it's imported. Yes, it's expensive. And y...       5
# 34523  I admit, I didn't get Sophie the Giraffe at fi...       4
# 34515  As every mom knows, you always want to give yo...       5
# ...                                                  ...     ...
# 35018  My son (now 2.5) LOVED his Sophie, and I bough...       1
# 34732  Received the product and smells like cheap rub...       1
# 34748  My daughter loves Sophie, but we received her ...       2
# 34556  Alright, first off didn't realize this was a s...       2
# 34687  I wanted to love this product and was excited ...       1
#
#                                             review_clean  sentiment  \
# 34892  Sophie oh Sophie your time has come My grandda...          1
# 34434  My MominLaw bought Sophie for my son when he w...          1
# 34442  Yes its imported Yes its expensive And yes I l...          1
# 34523  I admit I didnt get Sophie the Giraffe at firs...          1
# 34515  As every mom knows you always want to give you...          1
# ...                                                  ...        ...
# 35018  My son now 25 LOVED his Sophie and I bought on...          0
# 34732  Received the product and smells like cheap rub...          0
# 34748  My daughter loves Sophie but we received her a...          0
# 34556  Alright first off didnt realize this was a squ...          0
# 34687  I wanted to love this product and was excited ...          0
#
#        predicted_sentiment
# 34892         1.000000e+00
# 34434         1.000000e+00
# 34442         1.000000e+00
# 34523         1.000000e+00
# 34515         1.000000e+00
# ...                    ...
# 35018         1.209022e-04
# 34732         5.648463e-05
# 34748         4.766200e-05
# 34556         3.113063e-05
# 34687         2.428202e-09
#
# [723 rows x 6 columns]

# %% [markdown]
# ## Show the most positive reviews

# %%
giraffe_reviews['review'].iloc[0]
# Out:
